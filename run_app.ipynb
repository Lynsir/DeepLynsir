# %%
from util.util import importstr
from util.logconf import logging
log = logging.getLogger('')

def run(app, args):
    app_cls = importstr(*app.rsplit('.', 1))
    app_cls(args).run()

print('good luck!')
# Out:
# good luck!

# %%
run('app.example_app.ExampleApp', f'--epochs=100 --batch-size=8 test')
# Out:
# 2025-02-16 18:20:45,099 INFO     app.example_app:080:initModel()>>> Using CUDA; 2 devices.
# 2025-02-16 18:20:45,231 INFO     app.example_app:310:run()>>> Starting ExampleApp
# 		Namespace(batch_size=8, num_workers=4, epochs=100, comment='test', tb_prefix='ExampleApp', augmented=False)
# 2025-02-16 18:20:45,231 INFO     dataset.example_dataset:029:__init__()>>> 140 trn samples
# 2025-02-16 18:20:45,233 INFO     dataset.example_dataset:029:__init__()>>> 20 val samples
# 2025-02-16 18:20:45,233 INFO     app.example_app:317:run()>>> Epoch 1 of 100, 9/2 batches of size 8*2
# Training   Epoch 1: 100%|██████████████████████████████████████████| 9/9 [00:10<00:00,  1.12s/batch]
# 2025-02-16 18:20:55,561 INFO     app.example_app:174:logHistory()>>> E1 ExampleApp.logHistory
# 2025-02-16 18:20:55,562 INFO     app.example_app:196:logHistory()>>> E1 trn   0.6116 LOSS, 0.4295 DSC, 0.2735 IOU
# ...

# %% [markdown]
# 测试进度条

# %%
run('app.example_app.ExampleApp', f'--epochs=1 --batch-size=8 test')
# Out:
# 2025-02-16 20:04:56,116 INFO     app.example_app:068:initModel()>>> Using CUDA; 2 devices.
# 2025-02-16 20:04:56,246 INFO     app.example_app:269:run()>>> Starting ExampleApp
# 		Namespace(batch_size=8, num_workers=4, epochs=1, comment='test', tb_prefix='ExampleApp', augmented=False)
# 2025-02-16 20:04:56,247 INFO     dataset.example_dataset:029:__init__()>>> 140 trn samples
# 2025-02-16 20:04:56,249 INFO     dataset.example_dataset:029:__init__()>>> 20 val samples
# 2025-02-16 20:04:56,249 INFO     app.example_app:276:run()>>> Epoch 1 of 1, 9/2 batches of size 8*2
# Training   Epoch 1: 100%|██████████████████████████████████████████| 9/9 [00:10<00:00,  1.11s/batch]
# 2025-02-16 20:05:06,515 INFO     util.util:099:showMetrics()>>> E1 trn   0.6102 LOSS, 0.4355 DSC, 0.2783 IOU
# 2025-02-16 20:05:06,515 INFO     util.util:104:showMetrics()>>> E1 trn   0.2951 PRC , 0.8305 RCL, 0.4355 F1
# ...
