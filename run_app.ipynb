# %%
from util.util import importstr
from util.logconf import logging
log = logging.getLogger('')

def run(app, args):
    app_cls = importstr(*app.rsplit('.', 1))
    app_cls(args).run()

print('good job!')
# Out:
# good job!

# %%
run('app.example_app.ExampleApp', f'--epochs=100 --batch-size=8 test')
# Out:
# 2025-02-15 16:52:47,251 INFO     app.example_app:078:initModel()>>> Using CUDA; 2 devices.
# 2025-02-15 16:52:47,398 INFO     app.example_app:320:run()>>> Starting ExampleApp
# 		Namespace(batch_size=8, num_workers=4, epochs=100, comment='test', tb_prefix='ExampleApp', augmented=False)
# 2025-02-15 16:52:47,399 INFO     dataset.example_dataset:029:__init__()>>> 140 trn samples
# 2025-02-15 16:52:47,400 INFO     dataset.example_dataset:029:__init__()>>> 20 val samples
# 2025-02-15 16:52:47,400 INFO     app.example_app:327:run()>>> Epoch 1 of 100, 9/2 batches of size 8*2
# E:\miniconda3\envs\dlwpt-code-master\lib\site-packages\torch\cuda\nccl.py:15: UserWarning: PyTorch is not compiled with NCCL support
#   warnings.warn("PyTorch is not compiled with NCCL support")
# Training Epoch 1: 9it [00:09,  1.02s/it]
# 2025-02-15 16:52:56,831 INFO     app.example_app:185:logMetrics()>>> E1 ExampleApp logMetrics
# 2025-02-15 16:52:56,832 INFO     app.example_app:210:logMetrics()>>> E1 trn      0.6060 loss, 0.3067 precision, 0.8539 recall, 0.4513 f1
# 2025-02-15 16:52:56,832 INFO     app.example_app:216:logMetrics()>>> E1 trn_all  0.6060 loss, 0.3730 dsc_score,  75.2% ACC,  85.4% TP,  73.8% TN
# Validation Epoch 1: 2it [00:03,  1.66s/it]
# 2025-02-15 16:53:00,222 INFO     app.example_app:185:logMetrics()>>> E1 ExampleApp logMetrics
# 2025-02-15 16:53:00,222 INFO     app.example_app:210:logMetrics()>>> E1 val      0.4742 loss, 0.0000 precision, 0.0000 recall, 0.0000 f1
# 2025-02-15 16:53:00,222 INFO     app.example_app:216:logMetrics()>>> E1 val_all  0.4742 loss, 0.0000 dsc_score,  89.7% ACC,   0.0% TP, 100.0% TN
# 2025-02-15 16:53:02,010 INFO     app.example_app:327:run()>>> Epoch 2 of 100, 9/2 batches of size 8*2
# Training Epoch 2: 9it [00:04,  1.80it/s]
# 2025-02-15 16:53:09,911 INFO     app.example_app:185:logMetrics()>>> E2 ExampleApp logMetrics
# 2025-02-15 16:53:09,912 INFO     app.example_app:210:logMetrics()>>> E2 trn      0.5288 loss, 0.4792 precision, 0.8354 recall, 0.6091 f1
# 2025-02-15 16:53:09,912 INFO     app.example_app:216:logMetrics()>>> E2 trn_all  0.5288 loss, 0.4855 dsc_score,  87.2% ACC,  83.5% TP,  87.7% TN
# 2025-02-15 16:53:09,916 INFO     app.example_app:327:run()>>> Epoch 3 of 100, 9/2 batches of size 8*2
# Training Epoch 3: 9it [00:05,  1.76it/s]
# 2025-02-15 16:53:17,715 INFO     app.example_app:185:logMetrics()>>> E3 ExampleApp logMetrics
# 2025-02-15 16:53:17,715 INFO     app.example_app:210:logMetrics()>>> E3 trn      0.4852 loss, 0.5503 precision, 0.8097 recall, 0.6553 f1
# 2025-02-15 16:53:17,715 INFO     app.example_app:216:logMetrics()>>> E3 trn_all  0.4852 loss, 0.5091 dsc_score,  89.8% ACC,  81.0% TP,  91.0% TN
# 2025-02-15 16:53:17,719 INFO     app.example_app:327:run()>>> Epoch 4 of 100, 9/2 batches of size 8*2
# Training Epoch 4: 9it [00:04,  1.82it/s]
# 2025-02-15 16:53:25,534 INFO     app.example_app:185:logMetrics()>>> E4 ExampleApp logMetrics
# 2025-02-15 16:53:25,535 INFO     app.example_app:210:logMetrics()>>> E4 trn      0.4524 loss, 0.6159 precision, 0.8217 recall, 0.7041 f1
# 2025-02-15 16:53:25,535 INFO     app.example_app:216:logMetrics()>>> E4 trn_all  0.4524 loss, 0.5423 dsc_score,  91.8% ACC,  82.2% TP,  93.1% TN
# 2025-02-15 16:53:25,539 INFO     app.example_app:327:run()>>> Epoch 5 of 100, 9/2 batches of size 8*2
# Training Epoch 5: 9it [00:04,  1.81it/s]
# 2025-02-15 16:53:33,169 INFO     app.example_app:185:logMetrics()>>> E5 ExampleApp logMetrics
# 2025-02-15 16:53:33,169 INFO     app.example_app:210:logMetrics()>>> E5 trn      0.4255 loss, 0.6801 precision, 0.8290 recall, 0.7472 f1
# 2025-02-15 16:53:33,170 INFO     app.example_app:216:logMetrics()>>> E5 trn_all  0.4255 loss, 0.5785 dsc_score,  93.3% ACC,  82.9% TP,  94.7% TN
# Validation Epoch 5: 2it [00:03,  1.59s/it]
# 2025-02-15 16:53:36,375 INFO     app.example_app:185:logMetrics()>>> E5 ExampleApp logMetrics
# 2025-02-15 16:53:36,377 INFO     app.example_app:210:logMetrics()>>> E5 val      0.3973 loss, 0.8196 precision, 0.3828 recall, 0.5218 f1
# 2025-02-15 16:53:36,378 INFO     app.example_app:216:logMetrics()>>> E5 val_all  0.3973 loss, 0.3304 dsc_score,  92.8% ACC,  38.3% TP,  99.0% TN
# 2025-02-15 16:53:37,317 INFO     app.example_app:327:run()>>> Epoch 6 of 100, 9/2 batches of size 8*2
# Training Epoch 6: 9it [00:04,  1.81it/s]
# 2025-02-15 16:53:45,052 INFO     app.example_app:185:logMetrics()>>> E6 ExampleApp logMetrics
# 2025-02-15 16:53:45,053 INFO     app.example_app:210:logMetrics()>>> E6 trn      0.4117 loss, 0.6945 precision, 0.8355 recall, 0.7585 f1
# 2025-02-15 16:53:45,053 INFO     app.example_app:216:logMetrics()>>> E6 trn_all  0.4117 loss, 0.5914 dsc_score,  93.7% ACC,  83.6% TP,  95.0% TN
# 2025-02-15 16:53:45,056 INFO     app.example_app:327:run()>>> Epoch 7 of 100, 9/2 batches of size 8*2
# Training Epoch 7: 9it [00:04,  1.83it/s]
# 2025-02-15 16:53:52,679 INFO     app.example_app:185:logMetrics()>>> E7 ExampleApp logMetrics
# 2025-02-15 16:53:52,679 INFO     app.example_app:210:logMetrics()>>> E7 trn      0.4127 loss, 0.6825 precision, 0.7866 recall, 0.7309 f1
# 2025-02-15 16:53:52,680 INFO     app.example_app:216:logMetrics()>>> E7 trn_all  0.4127 loss, 0.5588 dsc_score,  93.1% ACC,  78.7% TP,  95.0% TN
# 2025-02-15 16:53:52,683 INFO     app.example_app:327:run()>>> Epoch 8 of 100, 9/2 batches of size 8*2
# Training Epoch 8: 9it [00:04,  1.83it/s]
# 2025-02-15 16:54:00,274 INFO     app.example_app:185:logMetrics()>>> E8 ExampleApp logMetrics
# 2025-02-15 16:54:00,275 INFO     app.example_app:210:logMetrics()>>> E8 trn      0.3931 loss, 0.7555 precision, 0.8209 recall, 0.7869 f1
# 2025-02-15 16:54:00,275 INFO     app.example_app:216:logMetrics()>>> E8 trn_all  0.3931 loss, 0.6266 dsc_score,  94.7% ACC,  82.1% TP,  96.4% TN
# 2025-02-15 16:54:00,278 INFO     app.example_app:327:run()>>> Epoch 9 of 100, 9/2 batches of size 8*2
# Training Epoch 9: 9it [00:04,  1.85it/s]
# 2025-02-15 16:54:07,859 INFO     app.example_app:185:logMetrics()>>> E9 ExampleApp logMetrics
# 2025-02-15 16:54:07,860 INFO     app.example_app:210:logMetrics()>>> E9 trn      0.3844 loss, 0.7703 precision, 0.8258 recall, 0.7971 f1
# 2025-02-15 16:54:07,860 INFO     app.example_app:216:logMetrics()>>> E9 trn_all  0.3844 loss, 0.6361 dsc_score,  95.0% ACC,  82.6% TP,  96.7% TN
# 2025-02-15 16:54:07,863 INFO     app.example_app:327:run()>>> Epoch 10 of 100, 9/2 batches of size 8*2
# Training Epoch 10: 9it [00:04,  1.88it/s]
# 2025-02-15 16:54:15,347 INFO     app.example_app:185:logMetrics()>>> E10 ExampleApp logMetrics
# 2025-02-15 16:54:15,348 INFO     app.example_app:210:logMetrics()>>> E10 trn      0.3771 loss, 0.7986 precision, 0.8323 recall, 0.8151 f1
# 2025-02-15 16:54:15,348 INFO     app.example_app:216:logMetrics()>>> E10 trn_all  0.3771 loss, 0.6451 dsc_score,  95.5% ACC,  83.2% TP,  97.2% TN
# Validation Epoch 10: 2it [00:03,  1.56s/it]
# 2025-02-15 16:54:19,202 INFO     app.example_app:185:logMetrics()>>> E10 ExampleApp logMetrics
# 2025-02-15 16:54:19,202 INFO     app.example_app:210:logMetrics()>>> E10 val      0.4289 loss, 0.4967 precision, 0.9439 recall, 0.6509 f1
# 2025-02-15 16:54:19,203 INFO     app.example_app:216:logMetrics()>>> E10 val_all  0.4289 loss, 0.4612 dsc_score,  89.5% ACC,  94.4% TP,  89.0% TN
# 2025-02-15 16:54:20,146 INFO     app.example_app:327:run()>>> Epoch 11 of 100, 9/2 batches of size 8*2
# Training Epoch 11: 9it [00:04,  1.83it/s]
# 2025-02-15 16:54:27,817 INFO     app.example_app:185:logMetrics()>>> E11 ExampleApp logMetrics
# 2025-02-15 16:54:27,818 INFO     app.example_app:210:logMetrics()>>> E11 trn      0.3738 loss, 0.7918 precision, 0.8400 recall, 0.8152 f1
# 2025-02-15 16:54:27,818 INFO     app.example_app:216:logMetrics()>>> E11 trn_all  0.3738 loss, 0.6499 dsc_score,  95.5% ACC,  84.0% TP,  97.0% TN
# 2025-02-15 16:54:27,820 INFO     app.example_app:327:run()>>> Epoch 12 of 100, 9/2 batches of size 8*2
# Training Epoch 12: 9it [00:04,  1.83it/s]
# 2025-02-15 16:54:35,472 INFO     app.example_app:185:logMetrics()>>> E12 ExampleApp logMetrics
# 2025-02-15 16:54:35,472 INFO     app.example_app:210:logMetrics()>>> E12 trn      0.3721 loss, 0.8004 precision, 0.8299 recall, 0.8149 f1
# 2025-02-15 16:54:35,473 INFO     app.example_app:216:logMetrics()>>> E12 trn_all  0.3721 loss, 0.6557 dsc_score,  95.5% ACC,  83.0% TP,  97.2% TN
# 2025-02-15 16:54:35,476 INFO     app.example_app:327:run()>>> Epoch 13 of 100, 9/2 batches of size 8*2
# Training Epoch 13: 9it [00:04,  1.81it/s]
# 2025-02-15 16:54:43,090 INFO     app.example_app:185:logMetrics()>>> E13 ExampleApp logMetrics
# 2025-02-15 16:54:43,091 INFO     app.example_app:210:logMetrics()>>> E13 trn      0.3733 loss, 0.7800 precision, 0.8184 recall, 0.7987 f1
# 2025-02-15 16:54:43,091 INFO     app.example_app:216:logMetrics()>>> E13 trn_all  0.3733 loss, 0.6525 dsc_score,  95.1% ACC,  81.8% TP,  96.9% TN
# 2025-02-15 16:54:43,094 INFO     app.example_app:327:run()>>> Epoch 14 of 100, 9/2 batches of size 8*2
# Training Epoch 14: 9it [00:04,  1.81it/s]
# 2025-02-15 16:54:50,680 INFO     app.example_app:185:logMetrics()>>> E14 ExampleApp logMetrics
# 2025-02-15 16:54:50,680 INFO     app.example_app:210:logMetrics()>>> E14 trn      0.3672 loss, 0.8068 precision, 0.8274 recall, 0.8170 f1
# 2025-02-15 16:54:50,681 INFO     app.example_app:216:logMetrics()>>> E14 trn_all  0.3672 loss, 0.6443 dsc_score,  95.6% ACC,  82.7% TP,  97.3% TN
# 2025-02-15 16:54:50,683 INFO     app.example_app:327:run()>>> Epoch 15 of 100, 9/2 batches of size 8*2
# Training Epoch 15: 9it [00:04,  1.84it/s]
# 2025-02-15 16:54:58,251 INFO     app.example_app:185:logMetrics()>>> E15 ExampleApp logMetrics
# 2025-02-15 16:54:58,252 INFO     app.example_app:210:logMetrics()>>> E15 trn      0.3645 loss, 0.8207 precision, 0.8267 recall, 0.8237 f1
# 2025-02-15 16:54:58,252 INFO     app.example_app:216:logMetrics()>>> E15 trn_all  0.3645 loss, 0.6668 dsc_score,  95.8% ACC,  82.7% TP,  97.6% TN
# Validation Epoch 15: 2it [00:03,  1.52s/it]
# 2025-02-15 16:55:01,328 INFO     app.example_app:185:logMetrics()>>> E15 ExampleApp logMetrics
# 2025-02-15 16:55:01,328 INFO     app.example_app:210:logMetrics()>>> E15 val      0.3600 loss, 0.8034 precision, 0.8071 recall, 0.8052 f1
# 2025-02-15 16:55:01,329 INFO     app.example_app:216:logMetrics()>>> E15 val_all  0.3600 loss, 0.5588 dsc_score,  96.0% ACC,  80.7% TP,  97.7% TN
# 2025-02-15 16:55:02,265 INFO     app.example_app:327:run()>>> Epoch 16 of 100, 9/2 batches of size 8*2
# Training Epoch 16: 9it [00:04,  1.84it/s]
# 2025-02-15 16:55:09,924 INFO     app.example_app:185:logMetrics()>>> E16 ExampleApp logMetrics
# 2025-02-15 16:55:09,926 INFO     app.example_app:210:logMetrics()>>> E16 trn      0.3634 loss, 0.8265 precision, 0.8236 recall, 0.8251 f1
# 2025-02-15 16:55:09,926 INFO     app.example_app:216:logMetrics()>>> E16 trn_all  0.3634 loss, 0.6590 dsc_score,  95.8% ACC,  82.4% TP,  97.7% TN
# 2025-02-15 16:55:09,929 INFO     app.example_app:327:run()>>> Epoch 17 of 100, 9/2 batches of size 8*2
# Training Epoch 17: 9it [00:04,  1.84it/s]
# 2025-02-15 16:55:17,506 INFO     app.example_app:185:logMetrics()>>> E17 ExampleApp logMetrics
# 2025-02-15 16:55:17,507 INFO     app.example_app:210:logMetrics()>>> E17 trn      0.3621 loss, 0.8151 precision, 0.8354 recall, 0.8252 f1
# 2025-02-15 16:55:17,507 INFO     app.example_app:216:logMetrics()>>> E17 trn_all  0.3621 loss, 0.6772 dsc_score,  95.8% ACC,  83.5% TP,  97.4% TN
# 2025-02-15 16:55:17,511 INFO     app.example_app:327:run()>>> Epoch 18 of 100, 9/2 batches of size 8*2
# Training Epoch 18: 9it [00:04,  1.84it/s]
# 2025-02-15 16:55:25,116 INFO     app.example_app:185:logMetrics()>>> E18 ExampleApp logMetrics
# 2025-02-15 16:55:25,117 INFO     app.example_app:210:logMetrics()>>> E18 trn      0.3589 loss, 0.8431 precision, 0.8337 recall, 0.8384 f1
# 2025-02-15 16:55:25,119 INFO     app.example_app:216:logMetrics()>>> E18 trn_all  0.3589 loss, 0.6798 dsc_score,  96.2% ACC,  83.4% TP,  97.9% TN
# 2025-02-15 16:55:25,121 INFO     app.example_app:327:run()>>> Epoch 19 of 100, 9/2 batches of size 8*2
# Training Epoch 19: 9it [00:04,  1.87it/s]
# 2025-02-15 16:55:32,663 INFO     app.example_app:185:logMetrics()>>> E19 ExampleApp logMetrics
# 2025-02-15 16:55:32,663 INFO     app.example_app:210:logMetrics()>>> E19 trn      0.3571 loss, 0.8451 precision, 0.8343 recall, 0.8397 f1
# 2025-02-15 16:55:32,663 INFO     app.example_app:216:logMetrics()>>> E19 trn_all  0.3571 loss, 0.6745 dsc_score,  96.2% ACC,  83.4% TP,  97.9% TN
# 2025-02-15 16:55:32,665 INFO     app.example_app:327:run()>>> Epoch 20 of 100, 9/2 batches of size 8*2
# Training Epoch 20: 9it [00:05,  1.72it/s]
# 2025-02-15 16:55:40,673 INFO     app.example_app:185:logMetrics()>>> E20 ExampleApp logMetrics
# 2025-02-15 16:55:40,675 INFO     app.example_app:210:logMetrics()>>> E20 trn      0.3549 loss, 0.8435 precision, 0.8518 recall, 0.8476 f1
# 2025-02-15 16:55:40,675 INFO     app.example_app:216:logMetrics()>>> E20 trn_all  0.3549 loss, 0.6873 dsc_score,  96.3% ACC,  85.2% TP,  97.9% TN
# Validation Epoch 20: 2it [00:03,  1.74s/it]
# 2025-02-15 16:55:44,202 INFO     app.example_app:185:logMetrics()>>> E20 ExampleApp logMetrics
# 2025-02-15 16:55:44,203 INFO     app.example_app:210:logMetrics()>>> E20 val      0.3499 loss, 0.8629 precision, 0.8175 recall, 0.8396 f1
# 2025-02-15 16:55:44,204 INFO     app.example_app:216:logMetrics()>>> E20 val_all  0.3499 loss, 0.5748 dsc_score,  96.8% ACC,  81.7% TP,  98.5% TN
# 2025-02-15 16:55:45,311 INFO     app.example_app:327:run()>>> Epoch 21 of 100, 9/2 batches of size 8*2
# Training Epoch 21: 9it [00:05,  1.65it/s]
# 2025-02-15 16:55:53,544 INFO     app.example_app:185:logMetrics()>>> E21 ExampleApp logMetrics
# 2025-02-15 16:55:53,544 INFO     app.example_app:210:logMetrics()>>> E21 trn      0.3542 loss, 0.8470 precision, 0.8486 recall, 0.8478 f1
# 2025-02-15 16:55:53,545 INFO     app.example_app:216:logMetrics()>>> E21 trn_all  0.3542 loss, 0.6938 dsc_score,  96.4% ACC,  84.9% TP,  97.9% TN
# 2025-02-15 16:55:53,548 INFO     app.example_app:327:run()>>> Epoch 22 of 100, 9/2 batches of size 8*2
# Training Epoch 22: 9it [00:05,  1.51it/s]
# 2025-02-15 16:56:02,049 INFO     app.example_app:185:logMetrics()>>> E22 ExampleApp logMetrics
# 2025-02-15 16:56:02,051 INFO     app.example_app:210:logMetrics()>>> E22 trn      0.3568 loss, 0.8227 precision, 0.8569 recall, 0.8394 f1
# 2025-02-15 16:56:02,051 INFO     app.example_app:216:logMetrics()>>> E22 trn_all  0.3568 loss, 0.6868 dsc_score,  96.1% ACC,  85.7% TP,  97.5% TN
# 2025-02-15 16:56:02,054 INFO     app.example_app:327:run()>>> Epoch 23 of 100, 9/2 batches of size 8*2
# Training Epoch 23: 9it [00:05,  1.65it/s]
# 2025-02-15 16:56:10,264 INFO     app.example_app:185:logMetrics()>>> E23 ExampleApp logMetrics
# 2025-02-15 16:56:10,265 INFO     app.example_app:210:logMetrics()>>> E23 trn      0.3527 loss, 0.8686 precision, 0.8350 recall, 0.8515 f1
# 2025-02-15 16:56:10,265 INFO     app.example_app:216:logMetrics()>>> E23 trn_all  0.3527 loss, 0.6949 dsc_score,  96.5% ACC,  83.5% TP,  98.3% TN
# 2025-02-15 16:56:10,270 INFO     app.example_app:327:run()>>> Epoch 24 of 100, 9/2 batches of size 8*2
# Training Epoch 24: 9it [00:06,  1.41it/s]
# 2025-02-15 16:56:19,477 INFO     app.example_app:185:logMetrics()>>> E24 ExampleApp logMetrics
# 2025-02-15 16:56:19,478 INFO     app.example_app:210:logMetrics()>>> E24 trn      0.3516 loss, 0.8598 precision, 0.8487 recall, 0.8542 f1
# 2025-02-15 16:56:19,479 INFO     app.example_app:216:logMetrics()>>> E24 trn_all  0.3516 loss, 0.6832 dsc_score,  96.5% ACC,  84.9% TP,  98.1% TN
# 2025-02-15 16:56:19,481 INFO     app.example_app:327:run()>>> Epoch 25 of 100, 9/2 batches of size 8*2
# Training Epoch 25: 9it [00:05,  1.68it/s]
# 2025-02-15 16:56:27,591 INFO     app.example_app:185:logMetrics()>>> E25 ExampleApp logMetrics
# 2025-02-15 16:56:27,592 INFO     app.example_app:210:logMetrics()>>> E25 trn      0.3547 loss, 0.8486 precision, 0.8365 recall, 0.8425 f1
# 2025-02-15 16:56:27,592 INFO     app.example_app:216:logMetrics()>>> E25 trn_all  0.3547 loss, 0.6818 dsc_score,  96.3% ACC,  83.6% TP,  98.0% TN
# Validation Epoch 25: 2it [00:03,  1.85s/it]
# 2025-02-15 16:56:31,403 INFO     app.example_app:185:logMetrics()>>> E25 ExampleApp logMetrics
# 2025-02-15 16:56:31,403 INFO     app.example_app:210:logMetrics()>>> E25 val      0.3899 loss, 0.5962 precision, 0.8774 recall, 0.7099 f1
# 2025-02-15 16:56:31,404 INFO     app.example_app:216:logMetrics()>>> E25 val_all  0.3899 loss, 0.5037 dsc_score,  92.6% ACC,  87.7% TP,  93.2% TN
# 2025-02-15 16:56:32,355 INFO     app.example_app:327:run()>>> Epoch 26 of 100, 9/2 batches of size 8*2
# Training Epoch 26: 9it [00:04,  1.82it/s]
# 2025-02-15 16:56:40,086 INFO     app.example_app:185:logMetrics()>>> E26 ExampleApp logMetrics
# 2025-02-15 16:56:40,086 INFO     app.example_app:210:logMetrics()>>> E26 trn      0.3498 loss, 0.8691 precision, 0.8524 recall, 0.8607 f1
# 2025-02-15 16:56:40,087 INFO     app.example_app:216:logMetrics()>>> E26 trn_all  0.3498 loss, 0.7022 dsc_score,  96.7% ACC,  85.2% TP,  98.3% TN
# 2025-02-15 16:56:40,089 INFO     app.example_app:327:run()>>> Epoch 27 of 100, 9/2 batches of size 8*2
# Training Epoch 27: 9it [00:05,  1.74it/s]
# 2025-02-15 16:56:47,890 INFO     app.example_app:185:logMetrics()>>> E27 ExampleApp logMetrics
# 2025-02-15 16:56:47,890 INFO     app.example_app:210:logMetrics()>>> E27 trn      0.3496 loss, 0.8768 precision, 0.8390 recall, 0.8575 f1
# 2025-02-15 16:56:47,891 INFO     app.example_app:216:logMetrics()>>> E27 trn_all  0.3496 loss, 0.7006 dsc_score,  96.7% ACC,  83.9% TP,  98.4% TN
# 2025-02-15 16:56:47,893 INFO     app.example_app:327:run()>>> Epoch 28 of 100, 9/2 batches of size 8*2
# Training Epoch 28: 9it [00:05,  1.63it/s]
# 2025-02-15 16:56:55,488 INFO     app.example_app:185:logMetrics()>>> E28 ExampleApp logMetrics
# 2025-02-15 16:56:55,488 INFO     app.example_app:210:logMetrics()>>> E28 trn      0.3585 loss, 0.8259 precision, 0.8156 recall, 0.8207 f1
# 2025-02-15 16:56:55,489 INFO     app.example_app:216:logMetrics()>>> E28 trn_all  0.3585 loss, 0.6587 dsc_score,  95.7% ACC,  81.6% TP,  97.7% TN
# 2025-02-15 16:56:55,491 INFO     app.example_app:327:run()>>> Epoch 29 of 100, 9/2 batches of size 8*2
# Training Epoch 29: 9it [00:05,  1.71it/s]
# 2025-02-15 16:57:03,200 INFO     app.example_app:185:logMetrics()>>> E29 ExampleApp logMetrics
# 2025-02-15 16:57:03,202 INFO     app.example_app:210:logMetrics()>>> E29 trn      0.3542 loss, 0.8669 precision, 0.8084 recall, 0.8367 f1
# 2025-02-15 16:57:03,202 INFO     app.example_app:216:logMetrics()>>> E29 trn_all  0.3542 loss, 0.6915 dsc_score,  96.2% ACC,  80.8% TP,  98.3% TN
# 2025-02-15 16:57:03,204 INFO     app.example_app:327:run()>>> Epoch 30 of 100, 9/2 batches of size 8*2
# Training Epoch 30: 9it [00:04,  1.83it/s]
# 2025-02-15 16:57:10,834 INFO     app.example_app:185:logMetrics()>>> E30 ExampleApp logMetrics
# 2025-02-15 16:57:10,834 INFO     app.example_app:210:logMetrics()>>> E30 trn      0.3526 loss, 0.8486 precision, 0.8416 recall, 0.8451 f1
# 2025-02-15 16:57:10,836 INFO     app.example_app:216:logMetrics()>>> E30 trn_all  0.3526 loss, 0.6709 dsc_score,  96.3% ACC,  84.2% TP,  98.0% TN
# Validation Epoch 30: 2it [00:03,  1.55s/it]
# 2025-02-15 16:57:13,974 INFO     app.example_app:185:logMetrics()>>> E30 ExampleApp logMetrics
# 2025-02-15 16:57:13,976 INFO     app.example_app:210:logMetrics()>>> E30 val      0.3428 loss, 0.8463 precision, 0.8947 recall, 0.8699 f1
# 2025-02-15 16:57:13,976 INFO     app.example_app:216:logMetrics()>>> E30 val_all  0.3428 loss, 0.5858 dsc_score,  97.2% ACC,  89.5% TP,  98.1% TN
# 2025-02-15 16:57:14,955 INFO     app.example_app:327:run()>>> Epoch 31 of 100, 9/2 batches of size 8*2
# Training Epoch 31: 9it [00:05,  1.80it/s]
# 2025-02-15 16:57:23,012 INFO     app.example_app:185:logMetrics()>>> E31 ExampleApp logMetrics
# 2025-02-15 16:57:23,014 INFO     app.example_app:210:logMetrics()>>> E31 trn      0.3481 loss, 0.8691 precision, 0.8526 recall, 0.8608 f1
# 2025-02-15 16:57:23,014 INFO     app.example_app:216:logMetrics()>>> E31 trn_all  0.3481 loss, 0.7086 dsc_score,  96.7% ACC,  85.3% TP,  98.3% TN
# 2025-02-15 16:57:23,017 INFO     app.example_app:327:run()>>> Epoch 32 of 100, 9/2 batches of size 8*2
# Training Epoch 32: 9it [00:04,  1.84it/s]
# 2025-02-15 16:57:30,755 INFO     app.example_app:185:logMetrics()>>> E32 ExampleApp logMetrics
# 2025-02-15 16:57:30,756 INFO     app.example_app:210:logMetrics()>>> E32 trn      0.3434 loss, 0.8914 precision, 0.8677 recall, 0.8793 f1
# 2025-02-15 16:57:30,756 INFO     app.example_app:216:logMetrics()>>> E32 trn_all  0.3434 loss, 0.7190 dsc_score,  97.2% ACC,  86.8% TP,  98.6% TN
# 2025-02-15 16:57:30,760 INFO     app.example_app:327:run()>>> Epoch 33 of 100, 9/2 batches of size 8*2
# Training Epoch 33: 9it [00:05,  1.80it/s]
# 2025-02-15 16:57:38,483 INFO     app.example_app:185:logMetrics()>>> E33 ExampleApp logMetrics
# 2025-02-15 16:57:38,483 INFO     app.example_app:210:logMetrics()>>> E33 trn      0.3448 loss, 0.8916 precision, 0.8552 recall, 0.8730 f1
# 2025-02-15 16:57:38,484 INFO     app.example_app:216:logMetrics()>>> E33 trn_all  0.3448 loss, 0.7090 dsc_score,  97.0% ACC,  85.5% TP,  98.6% TN
# 2025-02-15 16:57:38,487 INFO     app.example_app:327:run()>>> Epoch 34 of 100, 9/2 batches of size 8*2
# Training Epoch 34: 9it [00:04,  1.86it/s]
# 2025-02-15 16:57:46,068 INFO     app.example_app:185:logMetrics()>>> E34 ExampleApp logMetrics
# 2025-02-15 16:57:46,069 INFO     app.example_app:210:logMetrics()>>> E34 trn      0.3425 loss, 0.9072 precision, 0.8612 recall, 0.8836 f1
# 2025-02-15 16:57:46,069 INFO     app.example_app:216:logMetrics()>>> E34 trn_all  0.3425 loss, 0.7361 dsc_score,  97.3% ACC,  86.1% TP,  98.8% TN
# 2025-02-15 16:57:46,072 INFO     app.example_app:327:run()>>> Epoch 35 of 100, 9/2 batches of size 8*2
# Training Epoch 35: 9it [00:04,  1.85it/s]
# 2025-02-15 16:57:53,675 INFO     app.example_app:185:logMetrics()>>> E35 ExampleApp logMetrics
# 2025-02-15 16:57:53,675 INFO     app.example_app:210:logMetrics()>>> E35 trn      0.3538 loss, 0.8297 precision, 0.8433 recall, 0.8365 f1
# 2025-02-15 16:57:53,676 INFO     app.example_app:216:logMetrics()>>> E35 trn_all  0.3538 loss, 0.6769 dsc_score,  96.1% ACC,  84.3% TP,  97.7% TN
# Validation Epoch 35: 2it [00:03,  1.62s/it]
# 2025-02-15 16:57:56,949 INFO     app.example_app:185:logMetrics()>>> E35 ExampleApp logMetrics
# 2025-02-15 16:57:56,949 INFO     app.example_app:210:logMetrics()>>> E35 val      0.4346 loss, 0.4619 precision, 0.9158 recall, 0.6140 f1
# 2025-02-15 16:57:56,951 INFO     app.example_app:216:logMetrics()>>> E35 val_all  0.4346 loss, 0.4135 dsc_score,  88.1% ACC,  91.6% TP,  87.7% TN
# 2025-02-15 16:57:57,901 INFO     app.example_app:327:run()>>> Epoch 36 of 100, 9/2 batches of size 8*2
# Training Epoch 36: 9it [00:05,  1.69it/s]
# 2025-02-15 16:58:05,996 INFO     app.example_app:185:logMetrics()>>> E36 ExampleApp logMetrics
# 2025-02-15 16:58:05,997 INFO     app.example_app:210:logMetrics()>>> E36 trn      0.3579 loss, 0.8142 precision, 0.8309 recall, 0.8225 f1
# 2025-02-15 16:58:05,997 INFO     app.example_app:216:logMetrics()>>> E36 trn_all  0.3579 loss, 0.6671 dsc_score,  95.7% ACC,  83.1% TP,  97.4% TN
# 2025-02-15 16:58:06,000 INFO     app.example_app:327:run()>>> Epoch 37 of 100, 9/2 batches of size 8*2
# Training Epoch 37: 9it [00:04,  1.84it/s]
# 2025-02-15 16:58:13,600 INFO     app.example_app:185:logMetrics()>>> E37 ExampleApp logMetrics
# 2025-02-15 16:58:13,601 INFO     app.example_app:210:logMetrics()>>> E37 trn      0.3492 loss, 0.8607 precision, 0.8467 recall, 0.8537 f1
# 2025-02-15 16:58:13,601 INFO     app.example_app:216:logMetrics()>>> E37 trn_all  0.3492 loss, 0.6805 dsc_score,  96.5% ACC,  84.7% TP,  98.1% TN
# 2025-02-15 16:58:13,605 INFO     app.example_app:327:run()>>> Epoch 38 of 100, 9/2 batches of size 8*2
# Training Epoch 38: 9it [00:05,  1.74it/s]
# 2025-02-15 16:58:21,503 INFO     app.example_app:185:logMetrics()>>> E38 ExampleApp logMetrics
# 2025-02-15 16:58:21,503 INFO     app.example_app:210:logMetrics()>>> E38 trn      0.3452 loss, 0.8892 precision, 0.8494 recall, 0.8688 f1
# 2025-02-15 16:58:21,504 INFO     app.example_app:216:logMetrics()>>> E38 trn_all  0.3452 loss, 0.7177 dsc_score,  96.9% ACC,  84.9% TP,  98.6% TN
# 2025-02-15 16:58:21,507 INFO     app.example_app:327:run()>>> Epoch 39 of 100, 9/2 batches of size 8*2
# Training Epoch 39: 9it [00:04,  1.86it/s]
# 2025-02-15 16:58:29,066 INFO     app.example_app:185:logMetrics()>>> E39 ExampleApp logMetrics
# 2025-02-15 16:58:29,067 INFO     app.example_app:210:logMetrics()>>> E39 trn      0.3469 loss, 0.8697 precision, 0.8581 recall, 0.8639 f1
# 2025-02-15 16:58:29,068 INFO     app.example_app:216:logMetrics()>>> E39 trn_all  0.3469 loss, 0.7086 dsc_score,  96.8% ACC,  85.8% TP,  98.3% TN
# 2025-02-15 16:58:29,071 INFO     app.example_app:327:run()>>> Epoch 40 of 100, 9/2 batches of size 8*2
# Training Epoch 40: 9it [00:05,  1.71it/s]
# 2025-02-15 16:58:37,054 INFO     app.example_app:185:logMetrics()>>> E40 ExampleApp logMetrics
# 2025-02-15 16:58:37,054 INFO     app.example_app:210:logMetrics()>>> E40 trn      0.3435 loss, 0.9060 precision, 0.8465 recall, 0.8752 f1
# 2025-02-15 16:58:37,055 INFO     app.example_app:216:logMetrics()>>> E40 trn_all  0.3435 loss, 0.7217 dsc_score,  97.1% ACC,  84.7% TP,  98.8% TN
# Validation Epoch 40: 2it [00:03,  1.56s/it]
# 2025-02-15 16:58:40,209 INFO     app.example_app:185:logMetrics()>>> E40 ExampleApp logMetrics
# 2025-02-15 16:58:40,209 INFO     app.example_app:210:logMetrics()>>> E40 val      0.3615 loss, 0.7126 precision, 0.9080 recall, 0.7985 f1
# 2025-02-15 16:58:40,210 INFO     app.example_app:216:logMetrics()>>> E40 val_all  0.3615 loss, 0.5311 dsc_score,  95.3% ACC,  90.8% TP,  95.8% TN
# 2025-02-15 16:58:41,161 INFO     app.example_app:327:run()>>> Epoch 41 of 100, 9/2 batches of size 8*2
# Training Epoch 41: 9it [00:05,  1.78it/s]
# 2025-02-15 16:58:48,852 INFO     app.example_app:185:logMetrics()>>> E41 ExampleApp logMetrics
# 2025-02-15 16:58:48,853 INFO     app.example_app:210:logMetrics()>>> E41 trn      0.3470 loss, 0.8696 precision, 0.8568 recall, 0.8631 f1
# 2025-02-15 16:58:48,853 INFO     app.example_app:216:logMetrics()>>> E41 trn_all  0.3470 loss, 0.6949 dsc_score,  96.8% ACC,  85.7% TP,  98.3% TN
# 2025-02-15 16:58:48,856 INFO     app.example_app:327:run()>>> Epoch 42 of 100, 9/2 batches of size 8*2
# Training Epoch 42: 9it [00:04,  1.86it/s]
# 2025-02-15 16:58:56,432 INFO     app.example_app:185:logMetrics()>>> E42 ExampleApp logMetrics
# 2025-02-15 16:58:56,432 INFO     app.example_app:210:logMetrics()>>> E42 trn      0.3466 loss, 0.8806 precision, 0.8433 recall, 0.8615 f1
# 2025-02-15 16:58:56,433 INFO     app.example_app:216:logMetrics()>>> E42 trn_all  0.3466 loss, 0.7144 dsc_score,  96.8% ACC,  84.3% TP,  98.5% TN
# 2025-02-15 16:58:56,436 INFO     app.example_app:327:run()>>> Epoch 43 of 100, 9/2 batches of size 8*2
# Training Epoch 43: 9it [00:04,  1.82it/s]
# 2025-02-15 16:59:04,090 INFO     app.example_app:185:logMetrics()>>> E43 ExampleApp logMetrics
# 2025-02-15 16:59:04,090 INFO     app.example_app:210:logMetrics()>>> E43 trn      0.3445 loss, 0.9123 precision, 0.8293 recall, 0.8688 f1
# 2025-02-15 16:59:04,092 INFO     app.example_app:216:logMetrics()>>> E43 trn_all  0.3445 loss, 0.7119 dsc_score,  97.0% ACC,  82.9% TP,  98.9% TN
# 2025-02-15 16:59:04,094 INFO     app.example_app:327:run()>>> Epoch 44 of 100, 9/2 batches of size 8*2
# Training Epoch 44: 9it [00:04,  1.87it/s]
# 2025-02-15 16:59:11,640 INFO     app.example_app:185:logMetrics()>>> E44 ExampleApp logMetrics
# 2025-02-15 16:59:11,640 INFO     app.example_app:210:logMetrics()>>> E44 trn      0.3422 loss, 0.8858 precision, 0.8771 recall, 0.8814 f1
# 2025-02-15 16:59:11,641 INFO     app.example_app:216:logMetrics()>>> E44 trn_all  0.3422 loss, 0.7362 dsc_score,  97.2% ACC,  87.7% TP,  98.5% TN
# 2025-02-15 16:59:11,644 INFO     app.example_app:327:run()>>> Epoch 45 of 100, 9/2 batches of size 8*2
# Training Epoch 45: 9it [00:05,  1.79it/s]
# 2025-02-15 16:59:19,393 INFO     app.example_app:185:logMetrics()>>> E45 ExampleApp logMetrics
# 2025-02-15 16:59:19,393 INFO     app.example_app:210:logMetrics()>>> E45 trn      0.3404 loss, 0.9015 precision, 0.8747 recall, 0.8879 f1
# 2025-02-15 16:59:19,394 INFO     app.example_app:216:logMetrics()>>> E45 trn_all  0.3404 loss, 0.7383 dsc_score,  97.4% ACC,  87.5% TP,  98.7% TN
# Validation Epoch 45: 2it [00:03,  1.56s/it]
# 2025-02-15 16:59:22,543 INFO     app.example_app:185:logMetrics()>>> E45 ExampleApp logMetrics
# 2025-02-15 16:59:22,543 INFO     app.example_app:210:logMetrics()>>> E45 val      0.3445 loss, 0.8068 precision, 0.9293 recall, 0.8637 f1
# 2025-02-15 16:59:22,544 INFO     app.example_app:216:logMetrics()>>> E45 val_all  0.3445 loss, 0.5725 dsc_score,  97.0% ACC,  92.9% TP,  97.4% TN
# 2025-02-15 16:59:23,521 INFO     app.example_app:327:run()>>> Epoch 46 of 100, 9/2 batches of size 8*2
# Training Epoch 46: 9it [00:04,  1.84it/s]
# 2025-02-15 16:59:31,215 INFO     app.example_app:185:logMetrics()>>> E46 ExampleApp logMetrics
# 2025-02-15 16:59:31,215 INFO     app.example_app:210:logMetrics()>>> E46 trn      0.3415 loss, 0.9115 precision, 0.8534 recall, 0.8815 f1
# 2025-02-15 16:59:31,217 INFO     app.example_app:216:logMetrics()>>> E46 trn_all  0.3415 loss, 0.7207 dsc_score,  97.3% ACC,  85.3% TP,  98.9% TN
# 2025-02-15 16:59:31,751 INFO     app.example_app:327:run()>>> Epoch 47 of 100, 9/2 batches of size 8*2
# Training Epoch 47: 9it [00:04,  1.88it/s]
# 2025-02-15 16:59:39,281 INFO     app.example_app:185:logMetrics()>>> E47 ExampleApp logMetrics
# 2025-02-15 16:59:39,282 INFO     app.example_app:210:logMetrics()>>> E47 trn      0.3441 loss, 0.8674 precision, 0.8807 recall, 0.8740 f1
# 2025-02-15 16:59:39,282 INFO     app.example_app:216:logMetrics()>>> E47 trn_all  0.3441 loss, 0.7240 dsc_score,  97.0% ACC,  88.1% TP,  98.2% TN
# 2025-02-15 16:59:39,493 INFO     app.example_app:327:run()>>> Epoch 48 of 100, 9/2 batches of size 8*2
# Training Epoch 48: 9it [00:04,  1.86it/s]
# 2025-02-15 16:59:47,164 INFO     app.example_app:185:logMetrics()>>> E48 ExampleApp logMetrics
# 2025-02-15 16:59:47,164 INFO     app.example_app:210:logMetrics()>>> E48 trn      0.3483 loss, 0.8902 precision, 0.8138 recall, 0.8503 f1
# 2025-02-15 16:59:47,165 INFO     app.example_app:216:logMetrics()>>> E48 trn_all  0.3483 loss, 0.6823 dsc_score,  96.6% ACC,  81.4% TP,  98.6% TN
# 2025-02-15 16:59:47,872 INFO     app.example_app:327:run()>>> Epoch 49 of 100, 9/2 batches of size 8*2
# Training Epoch 49: 9it [00:04,  1.84it/s]
# 2025-02-15 16:59:55,482 INFO     app.example_app:185:logMetrics()>>> E49 ExampleApp logMetrics
# 2025-02-15 16:59:55,483 INFO     app.example_app:210:logMetrics()>>> E49 trn      0.3437 loss, 0.8851 precision, 0.8603 recall, 0.8725 f1
# 2025-02-15 16:59:55,483 INFO     app.example_app:216:logMetrics()>>> E49 trn_all  0.3437 loss, 0.7262 dsc_score,  97.0% ACC,  86.0% TP,  98.5% TN
# 2025-02-15 16:59:55,487 INFO     app.example_app:327:run()>>> Epoch 50 of 100, 9/2 batches of size 8*2
# Training Epoch 50: 9it [00:05,  1.75it/s]
# 2025-02-15 17:00:03,258 INFO     app.example_app:185:logMetrics()>>> E50 ExampleApp logMetrics
# 2025-02-15 17:00:03,258 INFO     app.example_app:210:logMetrics()>>> E50 trn      0.3438 loss, 0.8961 precision, 0.8494 recall, 0.8722 f1
# 2025-02-15 17:00:03,258 INFO     app.example_app:216:logMetrics()>>> E50 trn_all  0.3438 loss, 0.7310 dsc_score,  97.0% ACC,  84.9% TP,  98.7% TN
# Validation Epoch 50: 2it [00:03,  1.56s/it]
# 2025-02-15 17:00:06,405 INFO     app.example_app:185:logMetrics()>>> E50 ExampleApp logMetrics
# 2025-02-15 17:00:06,406 INFO     app.example_app:210:logMetrics()>>> E50 val      0.3480 loss, 0.8122 precision, 0.8658 recall, 0.8381 f1
# 2025-02-15 17:00:06,406 INFO     app.example_app:216:logMetrics()>>> E50 val_all  0.3480 loss, 0.5594 dsc_score,  96.5% ACC,  86.6% TP,  97.7% TN
# 2025-02-15 17:00:07,337 INFO     app.example_app:327:run()>>> Epoch 51 of 100, 9/2 batches of size 8*2
# Training Epoch 51: 9it [00:04,  1.81it/s]
# 2025-02-15 17:00:15,058 INFO     app.example_app:185:logMetrics()>>> E51 ExampleApp logMetrics
# 2025-02-15 17:00:15,058 INFO     app.example_app:210:logMetrics()>>> E51 trn      0.3402 loss, 0.9008 precision, 0.8734 recall, 0.8869 f1
# 2025-02-15 17:00:15,059 INFO     app.example_app:216:logMetrics()>>> E51 trn_all  0.3402 loss, 0.7269 dsc_score,  97.3% ACC,  87.3% TP,  98.7% TN
# 2025-02-15 17:00:15,062 INFO     app.example_app:327:run()>>> Epoch 52 of 100, 9/2 batches of size 8*2
# Training Epoch 52: 9it [00:05,  1.73it/s]
# 2025-02-15 17:00:23,004 INFO     app.example_app:185:logMetrics()>>> E52 ExampleApp logMetrics
# 2025-02-15 17:00:23,004 INFO     app.example_app:210:logMetrics()>>> E52 trn      0.3434 loss, 0.8916 precision, 0.8575 recall, 0.8743 f1
# 2025-02-15 17:00:23,005 INFO     app.example_app:216:logMetrics()>>> E52 trn_all  0.3434 loss, 0.7170 dsc_score,  97.1% ACC,  85.8% TP,  98.6% TN
# 2025-02-15 17:00:23,008 INFO     app.example_app:327:run()>>> Epoch 53 of 100, 9/2 batches of size 8*2
# Training Epoch 53: 9it [00:04,  1.86it/s]
# 2025-02-15 17:00:30,658 INFO     app.example_app:185:logMetrics()>>> E53 ExampleApp logMetrics
# 2025-02-15 17:00:30,659 INFO     app.example_app:210:logMetrics()>>> E53 trn      0.3435 loss, 0.8918 precision, 0.8585 recall, 0.8748 f1
# 2025-02-15 17:00:30,660 INFO     app.example_app:216:logMetrics()>>> E53 trn_all  0.3435 loss, 0.7114 dsc_score,  97.1% ACC,  85.8% TP,  98.6% TN
# 2025-02-15 17:00:30,668 INFO     app.example_app:327:run()>>> Epoch 54 of 100, 9/2 batches of size 8*2
# Training Epoch 54: 9it [00:04,  1.84it/s]
# 2025-02-15 17:00:38,379 INFO     app.example_app:185:logMetrics()>>> E54 ExampleApp logMetrics
# 2025-02-15 17:00:38,380 INFO     app.example_app:210:logMetrics()>>> E54 trn      0.3397 loss, 0.9165 precision, 0.8626 recall, 0.8887 f1
# 2025-02-15 17:00:38,380 INFO     app.example_app:216:logMetrics()>>> E54 trn_all  0.3397 loss, 0.7398 dsc_score,  97.4% ACC,  86.3% TP,  98.9% TN
# 2025-02-15 17:00:38,384 INFO     app.example_app:327:run()>>> Epoch 55 of 100, 9/2 batches of size 8*2
# Training Epoch 55: 9it [00:04,  1.81it/s]
# 2025-02-15 17:00:46,184 INFO     app.example_app:185:logMetrics()>>> E55 ExampleApp logMetrics
# 2025-02-15 17:00:46,185 INFO     app.example_app:210:logMetrics()>>> E55 trn      0.3377 loss, 0.9083 precision, 0.8903 recall, 0.8992 f1
# 2025-02-15 17:00:46,185 INFO     app.example_app:216:logMetrics()>>> E55 trn_all  0.3377 loss, 0.7493 dsc_score,  97.6% ACC,  89.0% TP,  98.8% TN
# Validation Epoch 55: 2it [00:03,  1.52s/it]
# 2025-02-15 17:00:49,259 INFO     app.example_app:185:logMetrics()>>> E55 ExampleApp logMetrics
# 2025-02-15 17:00:49,260 INFO     app.example_app:210:logMetrics()>>> E55 val      0.3787 loss, 0.6268 precision, 0.9043 recall, 0.7404 f1
# 2025-02-15 17:00:49,260 INFO     app.example_app:216:logMetrics()>>> E55 val_all  0.3787 loss, 0.5233 dsc_score,  93.5% ACC,  90.4% TP,  93.8% TN
# 2025-02-15 17:00:50,235 INFO     app.example_app:327:run()>>> Epoch 56 of 100, 9/2 batches of size 8*2
# Training Epoch 56: 9it [00:04,  1.83it/s]
# 2025-02-15 17:00:57,959 INFO     app.example_app:185:logMetrics()>>> E56 ExampleApp logMetrics
# 2025-02-15 17:00:57,959 INFO     app.example_app:210:logMetrics()>>> E56 trn      0.3375 loss, 0.9127 precision, 0.8854 recall, 0.8988 f1
# 2025-02-15 17:00:57,960 INFO     app.example_app:216:logMetrics()>>> E56 trn_all  0.3375 loss, 0.7476 dsc_score,  97.6% ACC,  88.5% TP,  98.9% TN
# 2025-02-15 17:00:57,962 INFO     app.example_app:327:run()>>> Epoch 57 of 100, 9/2 batches of size 8*2
# Training Epoch 57: 9it [00:05,  1.69it/s]
# 2025-02-15 17:01:06,001 INFO     app.example_app:185:logMetrics()>>> E57 ExampleApp logMetrics
# 2025-02-15 17:01:06,002 INFO     app.example_app:210:logMetrics()>>> E57 trn      0.3397 loss, 0.9073 precision, 0.8695 recall, 0.8880 f1
# 2025-02-15 17:01:06,002 INFO     app.example_app:216:logMetrics()>>> E57 trn_all  0.3397 loss, 0.7400 dsc_score,  97.4% ACC,  87.0% TP,  98.8% TN
# 2025-02-15 17:01:06,005 INFO     app.example_app:327:run()>>> Epoch 58 of 100, 9/2 batches of size 8*2
# Training Epoch 58: 9it [00:04,  1.80it/s]
# 2025-02-15 17:01:13,712 INFO     app.example_app:185:logMetrics()>>> E58 ExampleApp logMetrics
# 2025-02-15 17:01:13,713 INFO     app.example_app:210:logMetrics()>>> E58 trn      0.3377 loss, 0.9224 precision, 0.8714 recall, 0.8962 f1
# 2025-02-15 17:01:13,713 INFO     app.example_app:216:logMetrics()>>> E58 trn_all  0.3377 loss, 0.7462 dsc_score,  97.6% ACC,  87.1% TP,  99.0% TN
# 2025-02-15 17:01:13,716 INFO     app.example_app:327:run()>>> Epoch 59 of 100, 9/2 batches of size 8*2
# Training Epoch 59: 9it [00:05,  1.73it/s]
# 2025-02-15 17:01:21,643 INFO     app.example_app:185:logMetrics()>>> E59 ExampleApp logMetrics
# 2025-02-15 17:01:21,644 INFO     app.example_app:210:logMetrics()>>> E59 trn      0.3377 loss, 0.9143 precision, 0.8869 recall, 0.9004 f1
# 2025-02-15 17:01:21,644 INFO     app.example_app:216:logMetrics()>>> E59 trn_all  0.3377 loss, 0.7476 dsc_score,  97.7% ACC,  88.7% TP,  98.9% TN
# 2025-02-15 17:01:21,646 INFO     app.example_app:327:run()>>> Epoch 60 of 100, 9/2 batches of size 8*2
# Training Epoch 60: 9it [00:04,  1.85it/s]
# 2025-02-15 17:01:29,193 INFO     app.example_app:185:logMetrics()>>> E60 ExampleApp logMetrics
# 2025-02-15 17:01:29,193 INFO     app.example_app:210:logMetrics()>>> E60 trn      0.3400 loss, 0.9122 precision, 0.8890 recall, 0.9005 f1
# 2025-02-15 17:01:29,194 INFO     app.example_app:216:logMetrics()>>> E60 trn_all  0.3400 loss, 0.7494 dsc_score,  97.7% ACC,  88.9% TP,  98.8% TN
# Validation Epoch 60: 2it [00:03,  1.76s/it]
# 2025-02-15 17:01:32,746 INFO     app.example_app:185:logMetrics()>>> E60 ExampleApp logMetrics
# 2025-02-15 17:01:32,747 INFO     app.example_app:210:logMetrics()>>> E60 val      0.3683 loss, 0.6672 precision, 0.9366 recall, 0.7793 f1
# 2025-02-15 17:01:32,747 INFO     app.example_app:216:logMetrics()>>> E60 val_all  0.3683 loss, 0.5345 dsc_score,  94.5% ACC,  93.7% TP,  94.6% TN
# 2025-02-15 17:01:33,676 INFO     app.example_app:327:run()>>> Epoch 61 of 100, 9/2 batches of size 8*2
# Training Epoch 61: 9it [00:04,  1.81it/s]
# 2025-02-15 17:01:41,444 INFO     app.example_app:185:logMetrics()>>> E61 ExampleApp logMetrics
# 2025-02-15 17:01:41,444 INFO     app.example_app:210:logMetrics()>>> E61 trn      0.3434 loss, 0.8726 precision, 0.8888 recall, 0.8806 f1
# 2025-02-15 17:01:41,445 INFO     app.example_app:216:logMetrics()>>> E61 trn_all  0.3434 loss, 0.7247 dsc_score,  97.1% ACC,  88.9% TP,  98.2% TN
# 2025-02-15 17:01:41,447 INFO     app.example_app:327:run()>>> Epoch 62 of 100, 9/2 batches of size 8*2
# Training Epoch 62: 9it [00:05,  1.77it/s]
# 2025-02-15 17:01:49,110 INFO     app.example_app:185:logMetrics()>>> E62 ExampleApp logMetrics
# 2025-02-15 17:01:49,111 INFO     app.example_app:210:logMetrics()>>> E62 trn      0.3353 loss, 0.9145 precision, 0.9042 recall, 0.9093 f1
# 2025-02-15 17:01:49,111 INFO     app.example_app:216:logMetrics()>>> E62 trn_all  0.3353 loss, 0.7636 dsc_score,  97.8% ACC,  90.4% TP,  98.9% TN
# 2025-02-15 17:01:49,114 INFO     app.example_app:327:run()>>> Epoch 63 of 100, 9/2 batches of size 8*2
# Training Epoch 63: 9it [00:04,  1.84it/s]
# 2025-02-15 17:01:56,736 INFO     app.example_app:185:logMetrics()>>> E63 ExampleApp logMetrics
# 2025-02-15 17:01:56,737 INFO     app.example_app:210:logMetrics()>>> E63 trn      0.3356 loss, 0.9303 precision, 0.8858 recall, 0.9075 f1
# 2025-02-15 17:01:56,737 INFO     app.example_app:216:logMetrics()>>> E63 trn_all  0.3356 loss, 0.7692 dsc_score,  97.8% ACC,  88.6% TP,  99.1% TN
# 2025-02-15 17:01:56,740 INFO     app.example_app:327:run()>>> Epoch 64 of 100, 9/2 batches of size 8*2
# Training Epoch 64: 9it [00:04,  1.83it/s]
# 2025-02-15 17:02:04,337 INFO     app.example_app:185:logMetrics()>>> E64 ExampleApp logMetrics
# 2025-02-15 17:02:04,338 INFO     app.example_app:210:logMetrics()>>> E64 trn      0.3365 loss, 0.9130 precision, 0.8982 recall, 0.9056 f1
# 2025-02-15 17:02:04,338 INFO     app.example_app:216:logMetrics()>>> E64 trn_all  0.3365 loss, 0.7479 dsc_score,  97.8% ACC,  89.8% TP,  98.8% TN
# 2025-02-15 17:02:04,341 INFO     app.example_app:327:run()>>> Epoch 65 of 100, 9/2 batches of size 8*2
# Training Epoch 65: 9it [00:04,  1.85it/s]
# 2025-02-15 17:02:11,938 INFO     app.example_app:185:logMetrics()>>> E65 ExampleApp logMetrics
# 2025-02-15 17:02:11,939 INFO     app.example_app:210:logMetrics()>>> E65 trn      0.3375 loss, 0.9163 precision, 0.8843 recall, 0.9000 f1
# 2025-02-15 17:02:11,939 INFO     app.example_app:216:logMetrics()>>> E65 trn_all  0.3375 loss, 0.7530 dsc_score,  97.7% ACC,  88.4% TP,  98.9% TN
# Validation Epoch 65: 2it [00:03,  1.55s/it]
# 2025-02-15 17:02:15,072 INFO     app.example_app:185:logMetrics()>>> E65 ExampleApp logMetrics
# 2025-02-15 17:02:15,072 INFO     app.example_app:210:logMetrics()>>> E65 val      0.3374 loss, 0.9111 precision, 0.8501 recall, 0.8795 f1
# 2025-02-15 17:02:15,072 INFO     app.example_app:216:logMetrics()>>> E65 val_all  0.3374 loss, 0.5937 dsc_score,  97.6% ACC,  85.0% TP,  99.0% TN
# 2025-02-15 17:02:16,306 INFO     app.example_app:327:run()>>> Epoch 66 of 100, 9/2 batches of size 8*2
# Training Epoch 66: 9it [00:04,  1.82it/s]
# 2025-02-15 17:02:24,043 INFO     app.example_app:185:logMetrics()>>> E66 ExampleApp logMetrics
# 2025-02-15 17:02:24,043 INFO     app.example_app:210:logMetrics()>>> E66 trn      0.3340 loss, 0.9287 precision, 0.8975 recall, 0.9128 f1
# 2025-02-15 17:02:24,044 INFO     app.example_app:216:logMetrics()>>> E66 trn_all  0.3340 loss, 0.7657 dsc_score,  98.0% ACC,  89.8% TP,  99.1% TN
# 2025-02-15 17:02:24,265 INFO     app.example_app:327:run()>>> Epoch 67 of 100, 9/2 batches of size 8*2
# Training Epoch 67: 9it [00:04,  1.87it/s]
# 2025-02-15 17:02:31,961 INFO     app.example_app:185:logMetrics()>>> E67 ExampleApp logMetrics
# 2025-02-15 17:02:31,961 INFO     app.example_app:210:logMetrics()>>> E67 trn      0.3347 loss, 0.9219 precision, 0.9039 recall, 0.9128 f1
# 2025-02-15 17:02:31,962 INFO     app.example_app:216:logMetrics()>>> E67 trn_all  0.3347 loss, 0.7534 dsc_score,  97.9% ACC,  90.4% TP,  99.0% TN
# 2025-02-15 17:02:31,965 INFO     app.example_app:327:run()>>> Epoch 68 of 100, 9/2 batches of size 8*2
# Training Epoch 68: 9it [00:04,  1.82it/s]
# 2025-02-15 17:02:39,601 INFO     app.example_app:185:logMetrics()>>> E68 ExampleApp logMetrics
# 2025-02-15 17:02:39,601 INFO     app.example_app:210:logMetrics()>>> E68 trn      0.3334 loss, 0.9326 precision, 0.8983 recall, 0.9151 f1
# 2025-02-15 17:02:39,602 INFO     app.example_app:216:logMetrics()>>> E68 trn_all  0.3334 loss, 0.7651 dsc_score,  98.0% ACC,  89.8% TP,  99.1% TN
# 2025-02-15 17:02:39,606 INFO     app.example_app:327:run()>>> Epoch 69 of 100, 9/2 batches of size 8*2
# Training Epoch 69: 9it [00:04,  1.85it/s]
# 2025-02-15 17:02:47,262 INFO     app.example_app:185:logMetrics()>>> E69 ExampleApp logMetrics
# 2025-02-15 17:02:47,262 INFO     app.example_app:210:logMetrics()>>> E69 trn      0.3335 loss, 0.9308 precision, 0.8988 recall, 0.9145 f1
# 2025-02-15 17:02:47,263 INFO     app.example_app:216:logMetrics()>>> E69 trn_all  0.3335 loss, 0.7617 dsc_score,  98.0% ACC,  89.9% TP,  99.1% TN
# 2025-02-15 17:02:47,266 INFO     app.example_app:327:run()>>> Epoch 70 of 100, 9/2 batches of size 8*2
# Training Epoch 70: 9it [00:04,  1.82it/s]
# 2025-02-15 17:02:54,925 INFO     app.example_app:185:logMetrics()>>> E70 ExampleApp logMetrics
# 2025-02-15 17:02:54,926 INFO     app.example_app:210:logMetrics()>>> E70 trn      0.3320 loss, 0.9325 precision, 0.9101 recall, 0.9212 f1
# 2025-02-15 17:02:54,926 INFO     app.example_app:216:logMetrics()>>> E70 trn_all  0.3320 loss, 0.7729 dsc_score,  98.1% ACC,  91.0% TP,  99.1% TN
# Validation Epoch 70: 2it [00:03,  1.55s/it]
# 2025-02-15 17:02:58,066 INFO     app.example_app:185:logMetrics()>>> E70 ExampleApp logMetrics
# 2025-02-15 17:02:58,066 INFO     app.example_app:210:logMetrics()>>> E70 val      0.3323 loss, 0.9018 precision, 0.9163 recall, 0.9090 f1
# 2025-02-15 17:02:58,066 INFO     app.example_app:216:logMetrics()>>> E70 val_all  0.3323 loss, 0.6065 dsc_score,  98.1% ACC,  91.6% TP,  98.9% TN
# 2025-02-15 17:02:59,090 INFO     app.example_app:327:run()>>> Epoch 71 of 100, 9/2 batches of size 8*2
# Training Epoch 71: 9it [00:05,  1.68it/s]
# 2025-02-15 17:03:07,228 INFO     app.example_app:185:logMetrics()>>> E71 ExampleApp logMetrics
# 2025-02-15 17:03:07,228 INFO     app.example_app:210:logMetrics()>>> E71 trn      0.3311 loss, 0.9386 precision, 0.9110 recall, 0.9246 f1
# 2025-02-15 17:03:07,229 INFO     app.example_app:216:logMetrics()>>> E71 trn_all  0.3311 loss, 0.7767 dsc_score,  98.2% ACC,  91.1% TP,  99.2% TN
# 2025-02-15 17:03:07,232 INFO     app.example_app:327:run()>>> Epoch 72 of 100, 9/2 batches of size 8*2
# Training Epoch 72: 9it [00:04,  1.86it/s]
# 2025-02-15 17:03:14,784 INFO     app.example_app:185:logMetrics()>>> E72 ExampleApp logMetrics
# 2025-02-15 17:03:14,785 INFO     app.example_app:210:logMetrics()>>> E72 trn      0.3321 loss, 0.9343 precision, 0.9078 recall, 0.9209 f1
# 2025-02-15 17:03:14,785 INFO     app.example_app:216:logMetrics()>>> E72 trn_all  0.3321 loss, 0.7723 dsc_score,  98.1% ACC,  90.8% TP,  99.1% TN
# 2025-02-15 17:03:15,577 INFO     app.example_app:327:run()>>> Epoch 73 of 100, 9/2 batches of size 8*2
# Training Epoch 73: 9it [00:05,  1.77it/s]
# 2025-02-15 17:03:23,538 INFO     app.example_app:185:logMetrics()>>> E73 ExampleApp logMetrics
# 2025-02-15 17:03:23,539 INFO     app.example_app:210:logMetrics()>>> E73 trn      0.3319 loss, 0.9363 precision, 0.9067 recall, 0.9213 f1
# 2025-02-15 17:03:23,539 INFO     app.example_app:216:logMetrics()>>> E73 trn_all  0.3319 loss, 0.7717 dsc_score,  98.2% ACC,  90.7% TP,  99.2% TN
# 2025-02-15 17:03:23,542 INFO     app.example_app:327:run()>>> Epoch 74 of 100, 9/2 batches of size 8*2
# Training Epoch 74: 9it [00:04,  1.86it/s]
# 2025-02-15 17:03:31,116 INFO     app.example_app:185:logMetrics()>>> E74 ExampleApp logMetrics
# 2025-02-15 17:03:31,117 INFO     app.example_app:210:logMetrics()>>> E74 trn      0.3321 loss, 0.9343 precision, 0.9091 recall, 0.9215 f1
# 2025-02-15 17:03:31,118 INFO     app.example_app:216:logMetrics()>>> E74 trn_all  0.3321 loss, 0.7831 dsc_score,  98.2% ACC,  90.9% TP,  99.1% TN
# 2025-02-15 17:03:31,122 INFO     app.example_app:327:run()>>> Epoch 75 of 100, 9/2 batches of size 8*2
# Training Epoch 75: 9it [00:04,  1.85it/s]
# 2025-02-15 17:03:38,744 INFO     app.example_app:185:logMetrics()>>> E75 ExampleApp logMetrics
# 2025-02-15 17:03:38,745 INFO     app.example_app:210:logMetrics()>>> E75 trn      0.3324 loss, 0.9401 precision, 0.8969 recall, 0.9180 f1
# 2025-02-15 17:03:38,745 INFO     app.example_app:216:logMetrics()>>> E75 trn_all  0.3324 loss, 0.7712 dsc_score,  98.1% ACC,  89.7% TP,  99.2% TN
# Validation Epoch 75: 2it [00:03,  1.60s/it]
# 2025-02-15 17:03:41,974 INFO     app.example_app:185:logMetrics()>>> E75 ExampleApp logMetrics
# 2025-02-15 17:03:41,975 INFO     app.example_app:210:logMetrics()>>> E75 val      0.3343 loss, 0.8781 precision, 0.9249 recall, 0.9009 f1
# 2025-02-15 17:03:41,975 INFO     app.example_app:216:logMetrics()>>> E75 val_all  0.3343 loss, 0.6094 dsc_score,  97.9% ACC,  92.5% TP,  98.5% TN
# 2025-02-15 17:03:42,943 INFO     app.example_app:327:run()>>> Epoch 76 of 100, 9/2 batches of size 8*2
# Training Epoch 76: 9it [00:05,  1.75it/s]
# 2025-02-15 17:03:50,788 INFO     app.example_app:185:logMetrics()>>> E76 ExampleApp logMetrics
# 2025-02-15 17:03:50,789 INFO     app.example_app:210:logMetrics()>>> E76 trn      0.3327 loss, 0.9318 precision, 0.9051 recall, 0.9183 f1
# 2025-02-15 17:03:50,790 INFO     app.example_app:216:logMetrics()>>> E76 trn_all  0.3327 loss, 0.7581 dsc_score,  98.1% ACC,  90.5% TP,  99.1% TN
# 2025-02-15 17:03:50,792 INFO     app.example_app:327:run()>>> Epoch 77 of 100, 9/2 batches of size 8*2
# Training Epoch 77: 9it [00:04,  1.86it/s]
# 2025-02-15 17:03:58,349 INFO     app.example_app:185:logMetrics()>>> E77 ExampleApp logMetrics
# 2025-02-15 17:03:58,351 INFO     app.example_app:210:logMetrics()>>> E77 trn      0.3325 loss, 0.9321 precision, 0.9050 recall, 0.9183 f1
# 2025-02-15 17:03:58,351 INFO     app.example_app:216:logMetrics()>>> E77 trn_all  0.3325 loss, 0.7825 dsc_score,  98.1% ACC,  90.5% TP,  99.1% TN
# 2025-02-15 17:03:58,353 INFO     app.example_app:327:run()>>> Epoch 78 of 100, 9/2 batches of size 8*2
# Training Epoch 78: 9it [00:05,  1.74it/s]
# 2025-02-15 17:04:06,228 INFO     app.example_app:185:logMetrics()>>> E78 ExampleApp logMetrics
# 2025-02-15 17:04:06,229 INFO     app.example_app:210:logMetrics()>>> E78 trn      0.3335 loss, 0.9310 precision, 0.8982 recall, 0.9143 f1
# 2025-02-15 17:04:06,230 INFO     app.example_app:216:logMetrics()>>> E78 trn_all  0.3335 loss, 0.7654 dsc_score,  98.0% ACC,  89.8% TP,  99.1% TN
# 2025-02-15 17:04:06,232 INFO     app.example_app:327:run()>>> Epoch 79 of 100, 9/2 batches of size 8*2
# Training Epoch 79: 9it [00:04,  1.83it/s]
# 2025-02-15 17:04:13,849 INFO     app.example_app:185:logMetrics()>>> E79 ExampleApp logMetrics
# 2025-02-15 17:04:13,850 INFO     app.example_app:210:logMetrics()>>> E79 trn      0.3322 loss, 0.9343 precision, 0.9050 recall, 0.9194 f1
# 2025-02-15 17:04:13,850 INFO     app.example_app:216:logMetrics()>>> E79 trn_all  0.3322 loss, 0.7641 dsc_score,  98.1% ACC,  90.5% TP,  99.1% TN
# 2025-02-15 17:04:13,853 INFO     app.example_app:327:run()>>> Epoch 80 of 100, 9/2 batches of size 8*2
# Training Epoch 80: 9it [00:05,  1.69it/s]
# 2025-02-15 17:04:21,893 INFO     app.example_app:185:logMetrics()>>> E80 ExampleApp logMetrics
# 2025-02-15 17:04:21,893 INFO     app.example_app:210:logMetrics()>>> E80 trn      0.3341 loss, 0.9293 precision, 0.9030 recall, 0.9159 f1
# 2025-02-15 17:04:21,894 INFO     app.example_app:216:logMetrics()>>> E80 trn_all  0.3341 loss, 0.7443 dsc_score,  98.0% ACC,  90.3% TP,  99.1% TN
# Validation Epoch 80: 2it [00:03,  1.53s/it]
# 2025-02-15 17:04:24,993 INFO     app.example_app:185:logMetrics()>>> E80 ExampleApp logMetrics
# 2025-02-15 17:04:24,994 INFO     app.example_app:210:logMetrics()>>> E80 val      0.3403 loss, 0.8268 precision, 0.9347 recall, 0.8774 f1
# 2025-02-15 17:04:24,994 INFO     app.example_app:216:logMetrics()>>> E80 val_all  0.3403 loss, 0.5889 dsc_score,  97.3% ACC,  93.5% TP,  97.7% TN
# 2025-02-15 17:04:25,921 INFO     app.example_app:327:run()>>> Epoch 81 of 100, 9/2 batches of size 8*2
# Training Epoch 81: 9it [00:05,  1.69it/s]
# 2025-02-15 17:04:33,987 INFO     app.example_app:185:logMetrics()>>> E81 ExampleApp logMetrics
# 2025-02-15 17:04:33,987 INFO     app.example_app:210:logMetrics()>>> E81 trn      0.3325 loss, 0.9356 precision, 0.9038 recall, 0.9194 f1
# 2025-02-15 17:04:33,987 INFO     app.example_app:216:logMetrics()>>> E81 trn_all  0.3325 loss, 0.7651 dsc_score,  98.1% ACC,  90.4% TP,  99.2% TN
# 2025-02-15 17:04:33,991 INFO     app.example_app:327:run()>>> Epoch 82 of 100, 9/2 batches of size 8*2
# Training Epoch 82: 9it [00:04,  1.86it/s]
# 2025-02-15 17:04:41,567 INFO     app.example_app:185:logMetrics()>>> E82 ExampleApp logMetrics
# 2025-02-15 17:04:41,567 INFO     app.example_app:210:logMetrics()>>> E82 trn      0.3319 loss, 0.9322 precision, 0.9127 recall, 0.9223 f1
# 2025-02-15 17:04:41,568 INFO     app.example_app:216:logMetrics()>>> E82 trn_all  0.3319 loss, 0.7774 dsc_score,  98.2% ACC,  91.3% TP,  99.1% TN
# 2025-02-15 17:04:41,571 INFO     app.example_app:327:run()>>> Epoch 83 of 100, 9/2 batches of size 8*2
# Training Epoch 83: 9it [00:05,  1.75it/s]
# 2025-02-15 17:04:49,208 INFO     app.example_app:185:logMetrics()>>> E83 ExampleApp logMetrics
# 2025-02-15 17:04:49,208 INFO     app.example_app:210:logMetrics()>>> E83 trn      0.3313 loss, 0.9337 precision, 0.9160 recall, 0.9247 f1
# 2025-02-15 17:04:49,208 INFO     app.example_app:216:logMetrics()>>> E83 trn_all  0.3313 loss, 0.7816 dsc_score,  98.2% ACC,  91.6% TP,  99.1% TN
# 2025-02-15 17:04:49,211 INFO     app.example_app:327:run()>>> Epoch 84 of 100, 9/2 batches of size 8*2
# Training Epoch 84: 9it [00:04,  1.84it/s]
# 2025-02-15 17:04:56,847 INFO     app.example_app:185:logMetrics()>>> E84 ExampleApp logMetrics
# 2025-02-15 17:04:56,848 INFO     app.example_app:210:logMetrics()>>> E84 trn      0.3322 loss, 0.9331 precision, 0.9089 recall, 0.9209 f1
# 2025-02-15 17:04:56,848 INFO     app.example_app:216:logMetrics()>>> E84 trn_all  0.3322 loss, 0.7693 dsc_score,  98.1% ACC,  90.9% TP,  99.1% TN
# 2025-02-15 17:04:56,852 INFO     app.example_app:327:run()>>> Epoch 85 of 100, 9/2 batches of size 8*2
# Training Epoch 85: 9it [00:05,  1.76it/s]
# 2025-02-15 17:05:04,569 INFO     app.example_app:185:logMetrics()>>> E85 ExampleApp logMetrics
# 2025-02-15 17:05:04,569 INFO     app.example_app:210:logMetrics()>>> E85 trn      0.3315 loss, 0.9365 precision, 0.9084 recall, 0.9223 f1
# 2025-02-15 17:05:04,570 INFO     app.example_app:216:logMetrics()>>> E85 trn_all  0.3315 loss, 0.7805 dsc_score,  98.2% ACC,  90.8% TP,  99.2% TN
# Validation Epoch 85: 2it [00:03,  1.54s/it]
# 2025-02-15 17:05:07,689 INFO     app.example_app:185:logMetrics()>>> E85 ExampleApp logMetrics
# 2025-02-15 17:05:07,689 INFO     app.example_app:210:logMetrics()>>> E85 val      0.3410 loss, 0.8870 precision, 0.8370 recall, 0.8612 f1
# 2025-02-15 17:05:07,690 INFO     app.example_app:216:logMetrics()>>> E85 val_all  0.3410 loss, 0.5663 dsc_score,  97.2% ACC,  83.7% TP,  98.8% TN
# 2025-02-15 17:05:08,631 INFO     app.example_app:327:run()>>> Epoch 86 of 100, 9/2 batches of size 8*2
# Training Epoch 86: 9it [00:04,  1.84it/s]
# 2025-02-15 17:05:16,326 INFO     app.example_app:185:logMetrics()>>> E86 ExampleApp logMetrics
# 2025-02-15 17:05:16,327 INFO     app.example_app:210:logMetrics()>>> E86 trn      0.3316 loss, 0.9441 precision, 0.9014 recall, 0.9223 f1
# 2025-02-15 17:05:16,327 INFO     app.example_app:216:logMetrics()>>> E86 trn_all  0.3316 loss, 0.7747 dsc_score,  98.2% ACC,  90.1% TP,  99.3% TN
# 2025-02-15 17:05:16,332 INFO     app.example_app:327:run()>>> Epoch 87 of 100, 9/2 batches of size 8*2
# Training Epoch 87: 9it [00:04,  1.85it/s]
# 2025-02-15 17:05:23,926 INFO     app.example_app:185:logMetrics()>>> E87 ExampleApp logMetrics
# 2025-02-15 17:05:23,927 INFO     app.example_app:210:logMetrics()>>> E87 trn      0.3312 loss, 0.9389 precision, 0.9120 recall, 0.9253 f1
# 2025-02-15 17:05:23,927 INFO     app.example_app:216:logMetrics()>>> E87 trn_all  0.3312 loss, 0.7790 dsc_score,  98.2% ACC,  91.2% TP,  99.2% TN
# 2025-02-15 17:05:23,930 INFO     app.example_app:327:run()>>> Epoch 88 of 100, 9/2 batches of size 8*2
# Training Epoch 88: 9it [00:04,  1.85it/s]
# 2025-02-15 17:05:31,623 INFO     app.example_app:185:logMetrics()>>> E88 ExampleApp logMetrics
# 2025-02-15 17:05:31,624 INFO     app.example_app:210:logMetrics()>>> E88 trn      0.3300 loss, 0.9392 precision, 0.9221 recall, 0.9306 f1
# 2025-02-15 17:05:31,624 INFO     app.example_app:216:logMetrics()>>> E88 trn_all  0.3300 loss, 0.7778 dsc_score,  98.4% ACC,  92.2% TP,  99.2% TN
# 2025-02-15 17:05:31,627 INFO     app.example_app:327:run()>>> Epoch 89 of 100, 9/2 batches of size 8*2
# Training Epoch 89: 9it [00:04,  1.84it/s]
# 2025-02-15 17:05:39,265 INFO     app.example_app:185:logMetrics()>>> E89 ExampleApp logMetrics
# 2025-02-15 17:05:39,265 INFO     app.example_app:210:logMetrics()>>> E89 trn      0.3294 loss, 0.9400 precision, 0.9252 recall, 0.9325 f1
# 2025-02-15 17:05:39,266 INFO     app.example_app:216:logMetrics()>>> E89 trn_all  0.3294 loss, 0.7921 dsc_score,  98.4% ACC,  92.5% TP,  99.2% TN
# 2025-02-15 17:05:39,270 INFO     app.example_app:327:run()>>> Epoch 90 of 100, 9/2 batches of size 8*2
# Training Epoch 90: 9it [00:04,  1.84it/s]
# 2025-02-15 17:05:46,919 INFO     app.example_app:185:logMetrics()>>> E90 ExampleApp logMetrics
# 2025-02-15 17:05:46,919 INFO     app.example_app:210:logMetrics()>>> E90 trn      0.3293 loss, 0.9483 precision, 0.9143 recall, 0.9310 f1
# 2025-02-15 17:05:46,920 INFO     app.example_app:216:logMetrics()>>> E90 trn_all  0.3293 loss, 0.7889 dsc_score,  98.4% ACC,  91.4% TP,  99.3% TN
# Validation Epoch 90: 2it [00:03,  1.52s/it]
# 2025-02-15 17:05:50,010 INFO     app.example_app:185:logMetrics()>>> E90 ExampleApp logMetrics
# 2025-02-15 17:05:50,011 INFO     app.example_app:210:logMetrics()>>> E90 val      0.3310 loss, 0.9128 precision, 0.9140 recall, 0.9134 f1
# 2025-02-15 17:05:50,011 INFO     app.example_app:216:logMetrics()>>> E90 val_all  0.3310 loss, 0.6102 dsc_score,  98.2% ACC,  91.4% TP,  99.0% TN
# 2025-02-15 17:05:50,968 INFO     app.example_app:327:run()>>> Epoch 91 of 100, 9/2 batches of size 8*2
# Training Epoch 91: 9it [00:05,  1.79it/s]
# 2025-02-15 17:05:58,776 INFO     app.example_app:185:logMetrics()>>> E91 ExampleApp logMetrics
# 2025-02-15 17:05:58,777 INFO     app.example_app:210:logMetrics()>>> E91 trn      0.3287 loss, 0.9437 precision, 0.9246 recall, 0.9341 f1
# 2025-02-15 17:05:58,777 INFO     app.example_app:216:logMetrics()>>> E91 trn_all  0.3287 loss, 0.7836 dsc_score,  98.4% ACC,  92.5% TP,  99.3% TN
# 2025-02-15 17:05:58,781 INFO     app.example_app:327:run()>>> Epoch 92 of 100, 9/2 batches of size 8*2
# Training Epoch 92: 9it [00:05,  1.51it/s]
# 2025-02-15 17:06:07,448 INFO     app.example_app:185:logMetrics()>>> E92 ExampleApp logMetrics
# 2025-02-15 17:06:07,448 INFO     app.example_app:210:logMetrics()>>> E92 trn      0.3284 loss, 0.9528 precision, 0.9166 recall, 0.9344 f1
# 2025-02-15 17:06:07,449 INFO     app.example_app:216:logMetrics()>>> E92 trn_all  0.3284 loss, 0.7943 dsc_score,  98.5% ACC,  91.7% TP,  99.4% TN
# 2025-02-15 17:06:07,452 INFO     app.example_app:327:run()>>> Epoch 93 of 100, 9/2 batches of size 8*2
# Training Epoch 93: 9it [00:05,  1.70it/s]
# 2025-02-15 17:06:15,510 INFO     app.example_app:185:logMetrics()>>> E93 ExampleApp logMetrics
# 2025-02-15 17:06:15,510 INFO     app.example_app:210:logMetrics()>>> E93 trn      0.3282 loss, 0.9485 precision, 0.9235 recall, 0.9358 f1
# 2025-02-15 17:06:15,511 INFO     app.example_app:216:logMetrics()>>> E93 trn_all  0.3282 loss, 0.7993 dsc_score,  98.5% ACC,  92.3% TP,  99.3% TN
# 2025-02-15 17:06:15,513 INFO     app.example_app:327:run()>>> Epoch 94 of 100, 9/2 batches of size 8*2
# Training Epoch 94: 9it [00:05,  1.72it/s]
# 2025-02-15 17:06:23,465 INFO     app.example_app:185:logMetrics()>>> E94 ExampleApp logMetrics
# 2025-02-15 17:06:23,467 INFO     app.example_app:210:logMetrics()>>> E94 trn      0.3287 loss, 0.9477 precision, 0.9210 recall, 0.9342 f1
# 2025-02-15 17:06:23,467 INFO     app.example_app:216:logMetrics()>>> E94 trn_all  0.3287 loss, 0.8011 dsc_score,  98.5% ACC,  92.1% TP,  99.3% TN
# 2025-02-15 17:06:23,470 INFO     app.example_app:327:run()>>> Epoch 95 of 100, 9/2 batches of size 8*2
# Training Epoch 95: 9it [00:04,  1.84it/s]
# 2025-02-15 17:06:31,113 INFO     app.example_app:185:logMetrics()>>> E95 ExampleApp logMetrics
# 2025-02-15 17:06:31,115 INFO     app.example_app:210:logMetrics()>>> E95 trn      0.3278 loss, 0.9497 precision, 0.9263 recall, 0.9378 f1
# 2025-02-15 17:06:31,115 INFO     app.example_app:216:logMetrics()>>> E95 trn_all  0.3278 loss, 0.7980 dsc_score,  98.5% ACC,  92.6% TP,  99.3% TN
# Validation Epoch 95: 2it [00:03,  1.70s/it]
# 2025-02-15 17:06:34,595 INFO     app.example_app:185:logMetrics()>>> E95 ExampleApp logMetrics
# 2025-02-15 17:06:34,595 INFO     app.example_app:210:logMetrics()>>> E95 val      0.3307 loss, 0.9140 precision, 0.9160 recall, 0.9150 f1
# 2025-02-15 17:06:34,595 INFO     app.example_app:216:logMetrics()>>> E95 val_all  0.3307 loss, 0.6053 dsc_score,  98.2% ACC,  91.6% TP,  99.0% TN
# 2025-02-15 17:06:35,534 INFO     app.example_app:327:run()>>> Epoch 96 of 100, 9/2 batches of size 8*2
# Training Epoch 96: 9it [00:04,  1.83it/s]
# 2025-02-15 17:06:43,225 INFO     app.example_app:185:logMetrics()>>> E96 ExampleApp logMetrics
# 2025-02-15 17:06:43,226 INFO     app.example_app:210:logMetrics()>>> E96 trn      0.3279 loss, 0.9531 precision, 0.9215 recall, 0.9371 f1
# 2025-02-15 17:06:43,226 INFO     app.example_app:216:logMetrics()>>> E96 trn_all  0.3279 loss, 0.8018 dsc_score,  98.5% ACC,  92.2% TP,  99.4% TN
# 2025-02-15 17:06:43,228 INFO     app.example_app:327:run()>>> Epoch 97 of 100, 9/2 batches of size 8*2
# Training Epoch 97: 9it [00:05,  1.77it/s]
# 2025-02-15 17:06:50,995 INFO     app.example_app:185:logMetrics()>>> E97 ExampleApp logMetrics
# 2025-02-15 17:06:50,996 INFO     app.example_app:210:logMetrics()>>> E97 trn      0.3281 loss, 0.9450 precision, 0.9280 recall, 0.9364 f1
# 2025-02-15 17:06:50,996 INFO     app.example_app:216:logMetrics()>>> E97 trn_all  0.3281 loss, 0.7837 dsc_score,  98.5% ACC,  92.8% TP,  99.3% TN
# 2025-02-15 17:06:50,999 INFO     app.example_app:327:run()>>> Epoch 98 of 100, 9/2 batches of size 8*2
# Training Epoch 98: 9it [00:04,  1.83it/s]
# 2025-02-15 17:06:58,672 INFO     app.example_app:185:logMetrics()>>> E98 ExampleApp logMetrics
# 2025-02-15 17:06:58,672 INFO     app.example_app:210:logMetrics()>>> E98 trn      0.3281 loss, 0.9505 precision, 0.9219 recall, 0.9360 f1
# 2025-02-15 17:06:58,673 INFO     app.example_app:216:logMetrics()>>> E98 trn_all  0.3281 loss, 0.8034 dsc_score,  98.5% ACC,  92.2% TP,  99.3% TN
# 2025-02-15 17:06:58,675 INFO     app.example_app:327:run()>>> Epoch 99 of 100, 9/2 batches of size 8*2
# Training Epoch 99: 9it [00:05,  1.78it/s]
# 2025-02-15 17:07:06,465 INFO     app.example_app:185:logMetrics()>>> E99 ExampleApp logMetrics
# 2025-02-15 17:07:06,466 INFO     app.example_app:210:logMetrics()>>> E99 trn      0.3283 loss, 0.9461 precision, 0.9247 recall, 0.9353 f1
# 2025-02-15 17:07:06,466 INFO     app.example_app:216:logMetrics()>>> E99 trn_all  0.3283 loss, 0.7775 dsc_score,  98.5% ACC,  92.5% TP,  99.3% TN
# 2025-02-15 17:07:06,469 INFO     app.example_app:327:run()>>> Epoch 100 of 100, 9/2 batches of size 8*2
# Training Epoch 100: 9it [00:04,  1.84it/s]
# 2025-02-15 17:07:14,084 INFO     app.example_app:185:logMetrics()>>> E100 ExampleApp logMetrics
# 2025-02-15 17:07:14,085 INFO     app.example_app:210:logMetrics()>>> E100 trn      0.3298 loss, 0.9420 precision, 0.9194 recall, 0.9306 f1
# 2025-02-15 17:07:14,085 INFO     app.example_app:216:logMetrics()>>> E100 trn_all  0.3298 loss, 0.7895 dsc_score,  98.4% ACC,  91.9% TP,  99.2% TN
# Validation Epoch 100: 2it [00:03,  1.74s/it]
# 2025-02-15 17:07:17,607 INFO     app.example_app:185:logMetrics()>>> E100 ExampleApp logMetrics
# 2025-02-15 17:07:17,608 INFO     app.example_app:210:logMetrics()>>> E100 val      0.3322 loss, 0.9081 precision, 0.9093 recall, 0.9087 f1
# 2025-02-15 17:07:17,608 INFO     app.example_app:216:logMetrics()>>> E100 val_all  0.3322 loss, 0.6052 dsc_score,  98.1% ACC,  90.9% TP,  98.9% TN

# %% [markdown]
# 测试进度条

# %%
run('app.example_app.ExampleApp', f'--epochs=1 --batch-size=8 test')
# Out:
# 2025-02-15 17:27:49,923 INFO     app.example_app:078:initModel()>>> Using CUDA; 2 devices.
# 2025-02-15 17:27:50,068 INFO     app.example_app:320:run()>>> Starting ExampleApp
# 		Namespace(batch_size=8, num_workers=4, epochs=1, comment='test', tb_prefix='ExampleApp', augmented=False)
# 2025-02-15 17:27:50,069 INFO     dataset.example_dataset:029:__init__()>>> 140 trn samples
# 2025-02-15 17:27:50,070 INFO     dataset.example_dataset:029:__init__()>>> 20 val samples
# 2025-02-15 17:27:50,070 INFO     app.example_app:327:run()>>> Epoch 1 of 1, 9/2 batches of size 8*2
# E:\miniconda3\envs\dlwpt-code-master\lib\site-packages\torch\cuda\nccl.py:15: UserWarning: PyTorch is not compiled with NCCL support
#   warnings.warn("PyTorch is not compiled with NCCL support")
# Training Epoch 1: 9it [00:08,  1.00it/s]
# 2025-02-15 17:27:59,323 INFO     app.example_app:185:logMetrics()>>> E1 ExampleApp logMetrics
# 2025-02-15 17:27:59,325 INFO     app.example_app:210:logMetrics()>>> E1 trn      0.6067 loss, 0.2881 precision, 0.8000 recall, 0.4237 f1
# 2025-02-15 17:27:59,325 INFO     app.example_app:216:logMetrics()>>> E1 trn_all  0.6067 loss, 0.3657 dsc_score,  74.0% ACC,  80.0% TP,  73.2% TN
# Validation Epoch 1: 2it [00:03,  1.62s/it]
# 2025-02-15 17:28:02,611 INFO     app.example_app:185:logMetrics()>>> E1 ExampleApp logMetrics
# 2025-02-15 17:28:02,613 INFO     app.example_app:210:logMetrics()>>> E1 val      0.9946 loss, 0.0991 precision, 0.8506 recall, 0.1776 f1
# 2025-02-15 17:28:02,613 INFO     app.example_app:216:logMetrics()>>> E1 val_all  0.9946 loss, 0.1605 dsc_score,  18.7% ACC,  85.1% TP,  11.0% TN
