# %%
from util.util import importstr
from util.logconf import logging
log = logging.getLogger('')

# %%
def run(app, args):
    app_cls = importstr(*app.rsplit('.', 1))
    app_cls(args).run()

# %%
run('app.example_app.ExampleApp', f'--epochs=100 --batch-size=16 test')
# Out:
# 2025-02-07 20:30:59,126 INFO     pid:18260 app.example_app:069:initModel()>>> Using CUDA; 2 devices.
# 2025-02-07 20:30:59,150 INFO     pid:18260 app.example_app:340:run()>>> Starting ExampleApp, Namespace(batch_size=16, num_workers=4, epochs=100, comment='test', tb_prefix='ExampleApp', augmented=False)
# 2025-02-07 20:30:59,153 INFO     pid:18260 dataset.example_dataset:029:__init__()>>> <dataset.example_dataset.ExampleDataset object at 0x0000023466857F70>: 140 trn samples
# 2025-02-07 20:30:59,155 INFO     pid:18260 dataset.example_dataset:029:__init__()>>> <dataset.example_dataset.ExampleDataset object at 0x000002340B2FFAC0>: 20 val samples
# 2025-02-07 20:30:59,155 INFO     pid:18260 app.example_app:348:run()>>> Epoch 1 of 100, 5/1 batches of size 16*2
# 2025-02-07 20:30:59,157 WARNING  pid:18260 util.util:168:enumerateWithEstimate()>>> E1 Training ----/5, starting
# ...

# %%
# resize_size = (200,200)
run('app.example_app.ExampleApp', f'--epochs=100 --batch-size=16 test_200size')
# Out:
# 2025-02-07 21:54:27,338 INFO     pid:3140 app.example_app:072:initModel()>>> Using CUDA; 2 devices.
# 2025-02-07 21:54:27,422 INFO     pid:3140 app.example_app:347:run()>>> Starting ExampleApp, Namespace(batch_size=16, num_workers=4, epochs=100, comment='test_200size', tb_prefix='ExampleApp', augmented=False)
# 2025-02-07 21:54:27,423 INFO     pid:3140 dataset.example_dataset:029:__init__()>>> <dataset.example_dataset.ExampleDataset object at 0x000001539694BEE0>: 140 trn samples
# 2025-02-07 21:54:27,424 INFO     pid:3140 dataset.example_dataset:029:__init__()>>> <dataset.example_dataset.ExampleDataset object at 0x0000015396BDA920>: 20 val samples
# 2025-02-07 21:54:27,424 INFO     pid:3140 app.example_app:355:run()>>> Epoch 1 of 100, 5/1 batches of size 16*2
# 2025-02-07 21:54:27,449 WARNING  pid:3140 util.util:168:enumerateWithEstimate()>>> E1 Training ----/5, starting
# ...
